# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshikava/AI-Agents/blob/main/array_outliyers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
data=[2,5,6,7,8,70,56,39]
df=pd.DataFrame(data, columns=['sepal length (cm)'])
print(df['sepal length (cm)'].mean())
print(df['sepal length (cm)'].median())
mode_result = stats.mode(df['sepal length (cm)'])
mode_value = mode_result.mode # Corrected line
print(f"mode:{mode_value}")
std = np.std(df['sepal length (cm)'])
print(f"standard deviation:{std}")
var = np.var(df['sepal length (cm)'])
print(f"variance:{var}")
df.boxplot(column='sepal length (cm)')
plt.title('boxplot')
plt.show()
def remove_outliers(df, column):
  Q1 = df[column].quantile(0.25)
  Q2 = df[column].quantile(0.50)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  filtered_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
  return filtered_df
filtered_df = remove_outliers(df, 'sepal length (cm)')
print("data after removing outliers:")
print(filtered_df)
# Out:
# 24.125
# 7.5
# mode:2
# standard deviation:25.196415915760717
# variance:634.859375
# data after removing outliers:
#    sepal length (cm)
# 0                  2
# 1                  5
# 2                  6
# 3                  7
# 4                  8
# 5                 70
# 6                 56
# 7                 39
