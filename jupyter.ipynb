# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshikava/AI-Agents/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
X=np.array([[7],[10],[20],[28],[35]])

# %%
Z=linkage(X,method='complete')

# %%
plt.figure(figsize=(8,4))
dendrogram(Z,labels=X.flatten(),orientation='top')
plt.title('complete')
plt.ylabel('data points')
plt.ylabel('distance')
plt.show()
